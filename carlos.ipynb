# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelBinarizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import seaborn as sn
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
from mlxtend.plotting import plot_decision_regions
from scipy.stats import skew, kurtosis
from scipy.signal import welch
from scipy.signal import hilbert

import json 
import pandas as pd
import numpy as np
import os
import glob

from collections import Counter
from concurrent.futures import ThreadPoolExecutor, as_completed

# %% [markdown]
# ## Functions

# %%
def analyze_dataset(file_path):
    # Load dataset
    df = pd.read_csv(file_path)
    print("\n=== Basic Info ===")
    print(df.info())

    print("\n=== Statistical Summary ===")
    print(df.describe(include='all'))

    # Check for missing data
    print("\n=== Missing Values ===")
    print(df.isnull().sum())

    # Correlation matrix
    print("\n=== Correlation Matrix ===")
    print(df.corr(numeric_only=True))

    # Plot numeric columns
    numeric_cols = df.select_dtypes(include='number').columns
    if len(numeric_cols) > 0:
        df[numeric_cols].hist(figsize=(12, 8))
        plt.suptitle("Feature Distributions")
        plt.show()

# %%
analyze_dataset('battle2.csv')

# df = pd.read_csv('battle2.csv')
# Out:
# === Basic Info ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1902766 entries, 0 to 1902765
# Data columns (total 74 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unnamed: 0                      int64
#  1   battleTime                      object
#  2   arena.id                        float64
#  3   gameMode.id                     float64
#  4   average.startingTrophies        float64
#  5   winner.tag                      object
#  6   winner.startingTrophies         float64
#  7   winner.trophyChange             float64
#  8   winner.crowns                   float64
#  9   winner.kingTowerHitPoints       float64
#  10  winner.princessTowersHitPoints  object
#  11  winner.clan.tag                 object
#  12  winner.clan.badgeId             float64
#  13  loser.tag                       object
#  14  loser.startingTrophies          float64
#  15  loser.trophyChange              float64
#  16  loser.crowns                    float64
#  17  loser.kingTowerHitPoints        float64
#  18  loser.clan.tag                  object
#  19  loser.clan.badgeId              float64
#  20  loser.princessTowersHitPoints   object
#  21  tournamentTag                   float64
#  22  winner.card1.id                 int64
#  23  winner.card1.level              int64
#  24  winner.card2.id                 int64
#  25  winner.card2.level              int64
#  26  winner.card3.id                 int64
#  27  winner.card3.level              int64
#  28  winner.card4.id                 int64
#  29  winner.card4.level              int64
#  30  winner.card5.id                 int64
#  31  winner.card5.level              int64
#  32  winner.card6.id                 int64
#  33  winner.card6.level              int64
#  34  winner.card7.id                 int64
#  35  winner.card7.level              int64
#  36  winner.card8.id                 int64
#  37  winner.card8.level              int64
#  38  winner.cards.list               object
#  39  winner.totalcard.level          int64
#  40  winner.troop.count              int64
#  41  winner.structure.count          int64
#  42  winner.spell.count              int64
#  43  winner.common.count             int64
#  44  winner.rare.count               int64
#  45  winner.epic.count               int64
#  46  winner.legendary.count          int64
#  47  winner.elixir.average           float64
#  48  loser.card1.id                  int64
#  49  loser.card1.level               int64
#  50  loser.card2.id                  int64
#  51  loser.card2.level               int64
#  52  loser.card3.id                  int64
#  53  loser.card3.level               int64
#  54  loser.card4.id                  int64
#  55  loser.card4.level               int64
#  56  loser.card5.id                  int64
#  57  loser.card5.level               int64
#  58  loser.card6.id                  int64
#  59  loser.card6.level               int64
#  60  loser.card7.id                  int64
#  61  loser.card7.level               int64
#  62  loser.card8.id                  int64
#  63  loser.card8.level               int64
#  64  loser.cards.list                object
#  65  loser.totalcard.level           int64
#  66  loser.troop.count               int64
#  67  loser.structure.count           int64
#  68  loser.spell.count               int64
#  69  loser.common.count              int64
#  70  loser.rare.count                int64
#  71  loser.epic.count                int64
#  72  loser.legendary.count           int64
#  73  loser.elixir.average            float64
# dtypes: float64(16), int64(49), object(9)
# memory usage: 1.0+ GB
# None
#
# === Statistical Summary ===
#           Unnamed: 0                 battleTime      arena.id   gameMode.id  \
# count   1.902766e+06                    1902766  1.902766e+06  1.902766e+06
# unique           NaN                      98905           NaN           NaN
# top              NaN  2020-12-28 07:51:38+00:00           NaN           NaN
# freq             NaN                         46           NaN           NaN
# mean    9.513825e+05                        NaN  5.400005e+07  7.200002e+07
# std     5.492814e+05                        NaN  9.749779e+00  1.855584e+01
# min     0.000000e+00                        NaN  5.400000e+07  7.200001e+07
# 25%     4.756912e+05                        NaN  5.400005e+07  7.200001e+07
# 50%     9.513825e+05                        NaN  5.400005e+07  7.200001e+07
# 75%     1.427074e+06                        NaN  5.400005e+07  7.200004e+07
# max     1.902765e+06                        NaN  5.400005e+07  7.200004e+07
#
#         average.startingTrophies winner.tag  winner.startingTrophies  \
# count               1.902766e+06    1902766             1.902766e+06
# unique                       NaN    1124303                      NaN
# top                          NaN  #8GG8G0PP                      NaN
# freq                         NaN         98                      NaN
# mean                4.642513e+03        NaN             4.642834e+03
# std                 7.368766e+02        NaN             7.369244e+02
# min                 1.650000e+01        NaN             4.000000e+00
# 25%                 4.350000e+03        NaN             4.350000e+03
# 50%                 4.663500e+03        NaN             4.664000e+03
# 75%                 4.982000e+03        NaN             4.982000e+03
# max                 7.219000e+03        NaN             7.267000e+03
#
#         winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# count          1.902766e+06   1.902766e+06               1.902766e+06  ...
# unique                  NaN            NaN                        NaN  ...
# top                     NaN            NaN                        NaN  ...
# freq                    NaN            NaN                        NaN  ...
# mean           2.947904e+01   1.834215e+00               4.753051e+03  ...
# std            1.423307e+00   8.523671e-01               1.149820e+03  ...
# min            1.000000e+00   1.000000e+00               1.000000e+00  ...
# 25%            2.900000e+01   1.000000e+00               4.268000e+03  ...
# 50%            3.000000e+01   2.000000e+00               5.024000e+03  ...
# 75%            3.000000e+01   3.000000e+00               5.832000e+03  ...
# max            5.800000e+01   3.000000e+00               6.999000e+03  ...
#
#                                          loser.cards.list  \
# count                                             1902766
# unique                                            1068698
# top     [26000000, 26000026, 26000030, 26000041, 27000...
# freq                                                21764
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        loser.totalcard.level  loser.troop.count loser.structure.count  \
# count           1.902766e+06       1.902766e+06          1.902766e+06
# unique                   NaN                NaN                   NaN
# top                      NaN                NaN                   NaN
# freq                     NaN                NaN                   NaN
# mean            9.189358e+01       5.710833e+00          4.249319e-01
# std             1.475280e+01       1.115135e+00          6.124815e-01
# min             8.000000e+00       0.000000e+00          0.000000e+00
# 25%             8.400000e+01       5.000000e+00          0.000000e+00
# 50%             9.900000e+01       6.000000e+00          0.000000e+00
# 75%             1.040000e+02       6.000000e+00          1.000000e+00
# max             1.040000e+02       8.000000e+00          8.000000e+00
#
#         loser.spell.count  loser.common.count  loser.rare.count  \
# count        1.902766e+06        1.902766e+06      1.902766e+06
# unique                NaN                 NaN               NaN
# top                   NaN                 NaN               NaN
# freq                  NaN                 NaN               NaN
# mean         1.864236e+00        2.034011e+00      2.094918e+00
# std          9.118014e-01        1.311134e+00      1.282366e+00
# min          0.000000e+00        0.000000e+00      0.000000e+00
# 25%          1.000000e+00        1.000000e+00      1.000000e+00
# 50%          2.000000e+00        2.000000e+00      2.000000e+00
# 75%          2.000000e+00        3.000000e+00      3.000000e+00
# max          8.000000e+00        8.000000e+00      8.000000e+00
#
#         loser.epic.count loser.legendary.count  loser.elixir.average
# count       1.902766e+06          1.902766e+06          1.902766e+06
# unique               NaN                   NaN                   NaN
# top                  NaN                   NaN                   NaN
# freq                 NaN                   NaN                   NaN
# mean        2.250134e+00          1.620937e+00          3.880454e+00
# std         1.389392e+00          1.280780e+00          5.277516e-01
# min         0.000000e+00          0.000000e+00          1.500000e+00
# 25%         1.000000e+00          1.000000e+00          3.625000e+00
# 50%         2.000000e+00          1.000000e+00          3.875000e+00
# 75%         3.000000e+00          2.000000e+00          4.250000e+00
# max         8.000000e+00          8.000000e+00          7.553571e+00
#
# [11 rows x 74 columns]
#
# === Missing Values ===
# Unnamed: 0                  0
# battleTime                  0
# arena.id                    0
# gameMode.id                 0
# average.startingTrophies    0
#                            ..
# loser.common.count          0
# loser.rare.count            0
# loser.epic.count            0
# loser.legendary.count       0
# loser.elixir.average        0
# Length: 74, dtype: int64
#
# === Correlation Matrix ===
#                           Unnamed: 0  arena.id  gameMode.id  \
# Unnamed: 0                  1.000000  0.064112    -0.423709
# arena.id                    0.064112  1.000000     0.000854
# gameMode.id                -0.423709  0.000854     1.000000
# average.startingTrophies    0.062602  0.684847    -0.028543
# winner.startingTrophies     0.062515  0.684876    -0.028521
# ...                              ...       ...          ...
# loser.common.count         -0.012120  0.021976     0.006260
# loser.rare.count           -0.015969 -0.055716    -0.005965
# loser.epic.count            0.007396 -0.127917    -0.003504
# loser.legendary.count       0.020374  0.172053     0.003364
# loser.elixir.average       -0.004649 -0.015077    -0.010855
#
#                           average.startingTrophies  winner.startingTrophies  \
# Unnamed: 0                                0.062602                 0.062515
# arena.id                                  0.684847                 0.684876
# gameMode.id                              -0.028543                -0.028521
# average.startingTrophies                  1.000000                 0.999940
# winner.startingTrophies                   0.999940                 1.000000
# ...                                            ...                      ...
# loser.common.count                        0.066384                 0.066334
# loser.rare.count                         -0.019642                -0.019672
# loser.epic.count                         -0.091268                -0.091258
# loser.legendary.count                     0.050716                 0.050788
# loser.elixir.average                     -0.092884                -0.092843
#
#                           winner.trophyChange  winner.crowns  \
# Unnamed: 0                           0.005525      -0.014444
# arena.id                            -0.019427      -0.151435
# gameMode.id                         -0.002347       0.004994
# average.startingTrophies            -0.015526      -0.227476
# winner.startingTrophies             -0.026209      -0.227412
# ...                                       ...            ...
# loser.common.count                   0.005155      -0.017910
# loser.rare.count                     0.004234      -0.011687
# loser.epic.count                    -0.000833       0.039032
# loser.legendary.count               -0.008613      -0.012307
# loser.elixir.average                -0.002469       0.022738
#
#                           winner.kingTowerHitPoints  winner.clan.badgeId  \
# Unnamed: 0                                 0.020120            -0.006318
# arena.id                                   0.347078            -0.015463
# gameMode.id                               -0.001561             0.014195
# average.startingTrophies                   0.466009            -0.029139
# winner.startingTrophies                    0.466094            -0.029155
# ...                                             ...                  ...
# loser.common.count                         0.103478            -0.003707
# loser.rare.count                           0.062469            -0.003538
# loser.epic.count                          -0.115206             0.002139
# loser.legendary.count                     -0.043500             0.005044
# loser.elixir.average                      -0.088577             0.001660
#
#                           loser.startingTrophies  ...  loser.card8.level  \
# Unnamed: 0                              0.062681  ...           0.056219
# arena.id                                0.684736  ...           0.597090
# gameMode.id                            -0.028561  ...          -0.010804
# average.startingTrophies                0.999940  ...           0.774997
# winner.startingTrophies                 0.999760  ...           0.774818
# ...                                          ...  ...                ...
# loser.common.count                      0.066426  ...           0.129652
# loser.rare.count                       -0.019609  ...           0.118290
# loser.epic.count                       -0.091267  ...          -0.131151
# loser.legendary.count                   0.050639  ...          -0.108889
# loser.elixir.average                   -0.092913  ...          -0.031546
#
#                           loser.totalcard.level  loser.troop.count  \
# Unnamed: 0                             0.059892          -0.003282
# arena.id                               0.636776          -0.079502
# gameMode.id                           -0.011319          -0.009989
# average.startingTrophies               0.820308          -0.205876
# winner.startingTrophies                0.820127          -0.205803
# ...                                         ...                ...
# loser.common.count                     0.132388          -0.108607
# loser.rare.count                       0.117867          -0.110296
# loser.epic.count                      -0.134458           0.016171
# loser.legendary.count                 -0.107678           0.204072
# loser.elixir.average                  -0.028486           0.250646
#
#                           loser.structure.count  loser.spell.count  \
# Unnamed: 0                            -0.018946           0.016741
# arena.id                              -0.021378           0.111591
# gameMode.id                            0.006581           0.007796
# average.startingTrophies               0.054583           0.215121
# winner.startingTrophies                0.054558           0.215050
# ...                                         ...                ...
# loser.common.count                     0.153597           0.029652
# loser.rare.count                       0.289575          -0.059623
# loser.epic.count                      -0.225461           0.131671
# loser.legendary.count                 -0.202591          -0.113494
# loser.elixir.average                  -0.098407          -0.240438
#
#                           loser.common.count  loser.rare.count  \
# Unnamed: 0                         -0.012120         -0.015969
# arena.id                            0.021976         -0.055716
# gameMode.id                         0.006260         -0.005965
# average.startingTrophies            0.066384         -0.019642
# winner.startingTrophies             0.066334         -0.019672
# ...                                      ...               ...
# loser.common.count                  1.000000         -0.115164
# loser.rare.count                   -0.115164          1.000000
# loser.epic.count                   -0.520644         -0.384292
# loser.legendary.count              -0.343598         -0.466465
# loser.elixir.average               -0.404196          0.035223
#
#                           loser.epic.count  loser.legendary.count  \
# Unnamed: 0                        0.007396               0.020374
# arena.id                         -0.127917               0.172053
# gameMode.id                      -0.003504               0.003364
# average.startingTrophies         -0.091268               0.050716
# winner.startingTrophies          -0.091258               0.050788
# ...                                    ...                    ...
# loser.common.count               -0.520644              -0.343598
# loser.rare.count                 -0.384292              -0.466465
# loser.epic.count                  1.000000              -0.167050
# loser.legendary.count            -0.167050               1.000000
# loser.elixir.average              0.338017               0.011827
#
#                           loser.elixir.average
# Unnamed: 0                           -0.004649
# arena.id                             -0.015077
# gameMode.id                          -0.010855
# average.startingTrophies             -0.092884
# winner.startingTrophies              -0.092843
# ...                                        ...
# loser.common.count                   -0.404196
# loser.rare.count                      0.035223
# loser.epic.count                      0.338017
# loser.legendary.count                 0.011827
# loser.elixir.average                  1.000000
#
# [65 rows x 65 columns]

# %%
print(df.head())

for col in df.columns:
    print(col)
# Out:
#    Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 0           0  2020-12-27 19:01:19+00:00  54000050.0   72000044.0
# 1           1  2020-12-27 19:02:27+00:00  54000050.0   72000044.0
# 2           2  2020-12-27 19:02:41+00:00  54000050.0   72000044.0
# 3           3  2020-12-27 19:03:52+00:00  54000050.0   72000044.0
# 4           4  2020-12-27 19:04:10+00:00  54000050.0   72000044.0
#
#    average.startingTrophies  winner.tag  winner.startingTrophies  \
# 0                    5962.0  #28JV2JQCV                   5952.0
# 1                    6528.0  #2JGJG2P8U                   6532.0
# 2                    5968.0   #PUGPRU2U                   5985.0
# 3                    5222.0  #20YVLPP80                   5222.0
# 4                    6760.0  #2RVR9GQY8                   6759.0
#
#    winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 0                 31.0            1.0                     5832.0  ...
# 1                 29.0            1.0                     5762.0  ...
# 2                 27.0            3.0                     5832.0  ...
# 3                 30.0            1.0                     5832.0  ...
# 4                 30.0            1.0                     2825.0  ...
#
#                                     loser.cards.list loser.totalcard.level  \
# 0  [26000009, 26000015, 26000039, 26000048, 26000...                   104
# 1  [26000009, 26000013, 26000015, 26000023, 26000...                   104
# 2  [26000006, 26000011, 26000012, 26000017, 26000...                   104
# 3  [26000010, 26000011, 26000014, 27000006, 28000...                   104
# 4  [26000009, 26000013, 26000015, 26000035, 26000...                   104
#
#    loser.troop.count loser.structure.count  loser.spell.count  \
# 0                  6                     0                  2
# 1                  6                     0                  2
# 2                  6                     0                  2
# 3                  3                     1                  4
# 4                  6                     0                  2
#
#    loser.common.count  loser.rare.count  loser.epic.count  \
# 0                   0                 1                 6
# 1                   1                 1                 3
# 2                   2                 3                 3
# 3                   2                 2                 3
# 4                   1                 1                 4
#
#   loser.legendary.count  loser.elixir.average
# 0                     1              4.250000
# 1                     3              4.125000
# 2                     0              3.875000
# 3                     1              3.267857
# 4                     2              4.375000
#
# [5 rows x 74 columns]
# Unnamed: 0
# battleTime
# arena.id
# gameMode.id
# average.startingTrophies
# winner.tag
# winner.startingTrophies
# winner.trophyChange
# winner.crowns
# winner.kingTowerHitPoints
# winner.princessTowersHitPoints
# winner.clan.tag
# winner.clan.badgeId
# loser.tag
# loser.startingTrophies
# loser.trophyChange
# loser.crowns
# loser.kingTowerHitPoints
# loser.clan.tag
# loser.clan.badgeId
# loser.princessTowersHitPoints
# tournamentTag
# winner.card1.id
# winner.card1.level
# winner.card2.id
# winner.card2.level
# winner.card3.id
# winner.card3.level
# winner.card4.id
# winner.card4.level
# winner.card5.id
# winner.card5.level
# winner.card6.id
# winner.card6.level
# winner.card7.id
# winner.card7.level
# winner.card8.id
# winner.card8.level
# winner.cards.list
# winner.totalcard.level
# winner.troop.count
# winner.structure.count
# winner.spell.count
# winner.common.count
# winner.rare.count
# winner.epic.count
# winner.legendary.count
# winner.elixir.average
# loser.card1.id
# loser.card1.level
# loser.card2.id
# loser.card2.level
# loser.card3.id
# loser.card3.level
# loser.card4.id
# loser.card4.level
# loser.card5.id
# loser.card5.level
# loser.card6.id
# loser.card6.level
# loser.card7.id
# loser.card7.level
# loser.card8.id
# loser.card8.level
# loser.cards.list
# loser.totalcard.level
# loser.troop.count
# loser.structure.count
# loser.spell.count
# loser.common.count
# loser.rare.count
# loser.epic.count
# loser.legendary.count
# loser.elixir.average

# %%
df = df.dropna()
